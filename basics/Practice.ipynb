# %% [markdown]
# <a href="https://colab.research.google.com/github/metricmuseTA/python-learning/blob/main/basics/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd. DataFrame ({
    "name": ["Alice", "Bob", "Stephanie"],
    "score": [82, 78, 59]
})

# %%
df
# Out:
#         name  score
# 0      Alice     82
# 1        Bob     78
# 2  Stephanie     59

# %%
df["score"]
# Out:
# 0    82
# 1    78
# 2    59
# Name: score, dtype: int64

# %%
df [df ["score"] > 80]
# Out:
#     name  score
# 0  Alice     82

# %%
df [df ["score"] <= 80]
# Out:
#         name  score
# 1        Bob     78
# 2  Stephanie     59

# %%
df [ df ["score"] == 78]
# Out:
#   name  score
# 1  Bob     78

# %%
df [ df["name"] == "Bob"]
# Out:
#   name  score
# 1  Bob     78

# %%
df[ (df ["score"] >70) & (df ["score"] <90)]
# Out:
#     name  score
# 0  Alice     82
# 1    Bob     78

# %%
df [ (df ["score"] < 60) | (df ["name"] == "Alice")]
# Out:
#         name  score
# 0      Alice     82
# 2  Stephanie     59

# %%
from numpy import where
#filtering, calculated columns, and quick summary
#SQL mental model: where, calculated fields, aggregate metrics

# %%
#filter rows: score above 75
high_scores = df [ df ["score"] > 75]
high_scores
# Out:
#     name  score
# 0  Alice     82
# 1    Bob     78

# %%
# Create a calculated column (like a Tableau calculated field)
df ["passed"] = df ["score"] >=70

# %%
# Quick summary stats
df ["score"].mean(), df ["score"].min(), df ["score"].max()
# Out:
# (np.float64(73.0), 59, 82)

# %%
df
# Out:
#         name  score  passed
# 0      Alice     82    True
# 1        Bob     78    True
# 2  Stephanie     59   False

# %%
{
    "avg_score": df ["score"].mean(),
    "min_score":df['score'].min(),
    "max_score":df['score'].max()
}
# Out:
# {'avg_score': np.float64(73.0), 'min_score': 59, 'max_score': 82}
