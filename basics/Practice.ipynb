# %% [markdown]
# <a href="https://colab.research.google.com/github/metricmuseTA/python-learning/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd. DataFrame ({
    "name": ["Alice", "Bob", "Stephanie"],
    "score": [82, 78, 59]
})

# %%
df
# Out:
#         name  score
# 0      Alice     82
# 1        Bob     78
# 2  Stephanie     59

# %%
df["score"]
# Out:
# 0    82
# 1    78
# 2    59
# Name: score, dtype: int64

# %%
df [df ["score"] > 80]
# Out:
#     name  score
# 0  Alice     82

# %%
df [df ["score"] <= 80]
# Out:
#         name  score
# 1        Bob     78
# 2  Stephanie     59

# %%
df [ df ["score"] == 78]
# Out:
#   name  score
# 1  Bob     78

# %%
df [ df["name"] == "Bob"]
# Out:
#   name  score
# 1  Bob     78

# %%
df[ (df ["score"] >70) & (df ["score"] <90)]
# Out:
#     name  score
# 0  Alice     82
# 1    Bob     78

# %%
df [ (df ["score"] < 60) | (df ["name"] == "Alice")]
# Out:
#         name  score
# 0      Alice     82
# 2  Stephanie     59
